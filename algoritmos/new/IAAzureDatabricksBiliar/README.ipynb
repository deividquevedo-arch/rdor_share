# %% [markdown]
# ## Notas da criação de notebooks v2:

# %% [markdown]
#   Foi criado um novo notebook no repositório doencas_biliares (IAAzureDatabricksBiliar),
# com base na resolução de um bug da branch bugfix/fantasma:
#
# ntb_ia_doencas_biliares_algoritmo_v2
#
#   Este bug apareceu quando tentou-se padronizar os notebooks de doencas_biliares a partir do modelo de dii e colon,
# mas acabou diminuindo-se muito a precisão do algoritmo já anteriormente homologado.
# Porém, como não se percebeu o erro rapidamente, os notebooks “errados”, ou seja, com a padronização,
# já se encontravam modificados no repositório de doencas_biliares.
#
#   Com isso, foi criado um notebook extra de algoritmo ,na pasta model, com o sufixo v2!
# O novo notebook gera um novo resultado que já foi homologados e apresenta precisão aceitável novamente!
#
#   Sugere-se apagar as tabelas antigas, com os resultados errados (tb_diamond_mod_doencas_biliares_entrada,
# tb_diamond_mod_doencas_biliares_saida).
#
#   Como também excluir o notebooks antigo de algoritmo na pasta model (ntb_ia_doencas_biliares_algoritmo), para depois poder-se modificar o novo notebook e o notebook extracao para a retirada dos sufixos (v2) tanto do nome da tabela tb_diamond_mod_doencas_biliares_saida_v2(presente nos notebooks algoritmo_v2 e extracao), quanto do título do notebook algoritmo.
#
# Mantém-se o notebook de entrada, já que foi utilizado para gerar a nova amostra, sem apresentar erros. Alem disso, o notebook de extracao recebeu o sufixo v2 na sua tbl_saida, tornando-se tb_diamond_mod_doencas_biliares_saida_v2.
